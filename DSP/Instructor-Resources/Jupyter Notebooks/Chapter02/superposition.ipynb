# %%
import numpy as np
import matplotlib.pyplot as plt

# --------------------
# Time axis
t = np.linspace(0, 5, 500)
dt = t[1] - t[0]

# Inputs
x1 = np.sin(t)  # first input
x2 = np.cos(t)  # second input

alpha = 2
beta = 3

# --------------------
# (α) Linear system: y = R x
y1_a = x1
y2_a = x2
y_combo_a = alpha*x1 + beta*x2
y_linear_combo_a = alpha*y1_a + beta*y2_a

# (β) Non-linear system: y = x^2
y1_b = x1**2
y2_b = x2**2
y_combo_b = (alpha*x1 + beta*x2)**2
y_linear_combo_b = alpha*y1_b + beta*y2_b

# --------------------
# Plotting
fig, axs = plt.subplots(1,2, figsize=(12,5))
plt.subplots_adjust(wspace=0.3, bottom=0.2)

# (α) Linear
axs[0].plot(t, y_combo_a, label='y(α x1 + β x2)')
axs[0].plot(t, y_linear_combo_a, '--', label='α y1 + β y2')
axs[0].set_title('(α) y = R x (Linear)')
axs[0].grid(True)
axs[0].legend(loc='upper right')

# (β) Non-linear x^2
axs[1].plot(t, y_combo_b, label='y(α x1 + β x2)')
axs[1].plot(t, y_linear_combo_b, '--', label='α y1 + β y2')
axs[1].set_title('(β) y = x^2 (Non-linear)')
axs[1].grid(True)
axs[1].legend(loc='lower right')

# --------------------
# Common legend for inputs below both plots
fig.legend([plt.Line2D([0],[0], color='k', lw=2), plt.Line2D([0],[0], color='k', lw=2, linestyle='--')],
           ['x1(t) = sin(t)', 'x2(t) = cos(t)'],
           loc='lower center', ncol=2, frameon=False)

plt.show()
